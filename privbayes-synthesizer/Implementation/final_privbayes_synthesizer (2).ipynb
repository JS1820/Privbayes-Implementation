# %%
cd /
# Out:
# /

# %%
# !rm -rf privbayes-implementation/
# !git clone https://github.com/0hex7/privbayes-implementation.git
# Out:
# Cloning into 'privbayes-implementation'...
# remote: Enumerating objects: 1616, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 1616 (delta 108), reused 55 (delta 40), pack-reused 1443
# Receiving objects: 100% (1616/1616), 27.59 MiB | 30.38 MiB/s, done.
# Resolving deltas: 100% (812/812), done.

# %%
# %cd /privbayes-implementation/
# Out:
# /privbayes-implementation

# %%
# !python3 setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# %cd /privbayes-implementation/privbayes-synthesizer/code/
# Out:
# /privbayes-implementation/privbayes-synthesizer/code

# %%
# !python3 privbayes-nonnegativity.py --bucket 16 --dataset ../input-data/adult_with_human_column.csv
# Out:
# [+] Preprocessing the dataset to convert numerical values into buckets of size 16:
#
# [+] age is numerical. Bucketized values:
# -- Domain size for age: 16
#
# [+] fnlwgt is numerical. Bucketized values:
# -- Domain size for fnlwgt: 16
#
# [+] educational-num is numerical. Bucketized values:
# -- Domain size for educational-num: 16
#
# [+] capital-gain is numerical. Bucketized values:
# -- Domain size for capital-gain: 8
#
# [+] capital-loss is numerical. Bucketized values:
# -- Domain size for capital-loss: 15
#
# [+] hours-per-week is numerical. Bucketized values:
# -- Domain size for hours-per-week: 16
#
# [*] Column 'ishuman' has the same value (human) for all records. Removing from dataset.
# -- Columns removed:  {'ishuman': 'human'}
#
#
# [+] Head of the 'original' preprocessed dataset is:
#    age  workclass  fnlwgt     education  ...  capital-loss hours-per-week native-country income
# ...

# %%
# !python3 privbayes-nonnegativity.py --bucket 10 --dataset ../input-data/adult.csv
# Out:
# [+] Preprocessing the dataset to convert numerical values into buckets of size 10:
#
# [+] age is numerical. Bucketized values:
# -- Domain size for age: 10
#
# [+] fnlwgt is numerical. Bucketized values:
# -- Domain size for fnlwgt: 10
#
# [+] educational-num is numerical. Bucketized values:
# -- Domain size for educational-num: 10
#
# [+] capital-gain is numerical. Bucketized values:
# -- Domain size for capital-gain: 6
#
# [+] capital-loss is numerical. Bucketized values:
# -- Domain size for capital-loss: 10
#
# [+] hours-per-week is numerical. Bucketized values:
# -- Domain size for hours-per-week: 10
# -- Columns removed:  {}
#
#
# [+] Head of the 'original' preprocessed dataset is:
#    age  workclass  fnlwgt     education  ...  capital-loss hours-per-week native-country income
# 0    1    Private       1          11th  ...             0              3  United-States  <=50K
# 1    2    Private       0       HS-grad  ...             0              4  United-States  <=50K
# ...
